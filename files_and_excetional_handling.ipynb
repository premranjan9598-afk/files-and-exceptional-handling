# %% [markdown]
# 1- What is the difference between interpreted and compiled languages ?
# =>>compiled: Code is translated to machine code before execution
#
# Interpreted: Code is executed line by line at runtime (e.g., Python, JavaScript). Easier debugging, slower than compiled.

# %% [markdown]
# 2-What is exception handling in Python?
# =>>It is a mechanism to handle runtime errors using try, except, else, and finally blocks so that the program does not crash unexpectedly.

# %% [markdown]
# 3- What is the purpose of the finally block in exception handling ?
# =>> finally always executes whether an exception occurs or not. It is used for cleanup tasks like closing files or releasing resources.

# %% [markdown]
# 4-What is logging in Python?
# =>>Logging is a way to record events, errors, and messages during program execution using the logging module for debugging, monitoring, and auditing.

# %% [markdown]
# 5-What is the significance of the __del__ method in Python?
# =>>__del__() is a destructor method called when an object is about to be destroyed. It is used to clean up resources and though its use is generally discouraged due to unpredictability.

# %% [markdown]
# 6- What is the difference between import and from ... import in Python?
# =>>import module used to Access with module.name
#
# from module import name used to Access directly as name
# The second is shorter but may cause name conflicts.

# %% [markdown]
# 7- How can you handle multiple exceptions in Python?
# =>> Always catch specific exceptions first,Use Exception only for logging or when you truly need to catch all errors,Log exceptions for debugging.
# Avoid bare except without specifying an exception type

# %% [markdown]
# 8- What is the purpose of the with statement when handling files in Python?
# =>>It ensures automatic closing of files and resource management even if an exception occurs.

# %% [markdown]
# 9-What is the difference between multithreading and multiprocessing?
# =>>Multithreading: Multiple threads in one process and shares memory
#
# Multiprocessing: Multiple processes:separate memory and better for CPU-bound tasks.

# %% [markdown]
# 10-What are the advantages of using logging in a program?
# =>>Tracks program execution,Helps debug errors,Records runtime information,Useful in production systems

# %% [markdown]
# 11-What is memory management in Python?
# =>>It refers to how Python allocates, tracks, and deallocates memory automatically using reference counting and garbage collection.

# %% [markdown]
# 12-What are the basic steps involved in exception handling in Python?
# =>>Write risky code inside try
#
# Catch errors using except
#
# Optional else for no-exception code
#
# Use finally for cleanup

# %% [markdown]
# 13-Why is memory management important in Python?
# =>>Prevents memory leaks,Optimizes performance,Ensures efficient resource utilization

# %% [markdown]
# 14-What is the role of try and except in exception handling?
# =>>try: Wraps code that may cause errors
#
# except: Handles the exception gracefully

# %% [markdown]
# 15-How does Python's garbage collection system work?
# =>>Reference counting: Frees memory when object reference becomes zero
#
# Cyclic garbage collector: Detects and cleans circular references

# %% [markdown]
# 16-What is the purpose of the else block in exception handling?
# =>>Runs only if no exception occurs in the try block.

# %% [markdown]
# 17-What are the common logging levels in Python?
# =>>DEBUG,INFO,WARNING,ERROR,CRITICAL

# %% [markdown]
# 18-What is the difference between os.fork() and multiprocessing in Python?
# =>>os.fork(): Creates a child process in Unix systems only
#
# multiprocessing: Cross-platform module for creating processes in Python

# %% [markdown]
# 19-What is the importance of closing a file in Python?
# =>>Frees system resources,Ensures data is properly saved,Prevents file corruption

# %% [markdown]
# 20-What is the difference between file.read() and file.readline() in Python?
# =>>read() → Reads entire file
#
# readline() → Reads one line at a time

# %% [markdown]
# 21-What is the logging module in Python used for?
# =>>Used to record messages, warnings, errors, and runtime events in a structured and configurable way.

# %% [markdown]
# 22-What is the os module in Python used for in file handling?
# =>>Creating/deleting files and folders,Checking file existence,Path operations

# %% [markdown]
# 23-What are the challenges associated with memory management in Python?
# =>>Memory leaks
#
# Circular references
#
# High memory overhead
#
# Fragmentation
#
# Limited control
#
# Global Interpreter Lock

# %% [markdown]
# 24- How do you raise an exception manually in Python?
# =>>Use the raise keyword

# %% [markdown]
# 25-Why is it important to use multithreading in certain applications?
# =>>Improves responsiveness,Efficient I/O handling,Better resource utilization,Concurrency,Real-time systems

# %% [markdown]
#                                 PRACTICAL QUESTIONS

# %%
#How can you open a file for writing in Python and write a string to it

with open("data.txt", "w") as f:
    f.write("Hello, Python!")

# %%
#Write a Python program to read the contents of a file and print each line
with open("data.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, Python!

# %%
#How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    with open("missing.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File does not exist.")
# Out:
# File does not exist.

# %%
#Write a Python script that reads from one file and writes its content to another file
with open("source.txt", "r") as src, open("dest.txt", "w") as dst:
    dst.write(src.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3926854409.py in <cell line: 0>()
#       1 #Write a Python script that reads from one file and writes its content to another file
# ----> 2 with open("source.txt", "r") as src, open("dest.txt", "w") as dst:
#       3     dst.write(src.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
# How would you catch and handle division by zero error in Python
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
#Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred")
# Out:
# ERROR:root:Division by zero occurred

# %%
#How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging

logging.basicConfig(level=logging.DEBUG)
logging.info("This is info")
logging.warning("This is warning")
logging.error("This is error")
logging.critical("This is critical")
# Out:
# WARNING:root:This is warning
# ERROR:root:This is error
# CRITICAL:root:This is critical

# %%
#Write a program to handle a file opening error using exception handling
try:
    f = open("file.txt", "r")
    print(f.read())
    f.close()
except IOError:
    print("File cannot be opened.")
# Out:
# File cannot be opened.

# %%
#How can you read a file line by line and store its content in a list in Python
try:
    with open("data.txt", "r") as f:
        lines = [line.strip() for line in f]
    print(lines)
except FileNotFoundError:
    print("Error: 'data.txt' not found. Please create the file or check the path.")
# Out:
# Error: 'data.txt' not found. Please create the file or check the path.

# %%
#How can you append data to an existing file in Python
with open("data.txt", "a") as f:
    f.write("\nNew line added.")

# %%
#Write a Python program that uses a try-except block to handle an error when attempting to access a
#dictionary key that doesn't exist

data = {"a": 10}

try:
    print(data["b"])
except KeyError:
    print("Key does not exist.")
# Out:
# Key does not exist.

# %%
#Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    x = int("abc")
    y = 10 / 0
except ValueError:
    print("Value error occurred")
except ZeroDivisionError:
    print("Division by zero")
# Out:
# Value error occurred

# %%
#How would you check if a file exists before attempting to read it in Python
import os

if os.path.exists("data.txt"):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
# Write a program that uses the logging module to log both informational and error messages
import logging

logging.basicConfig(filename="app.log", level=logging.INFO)

logging.info("Program started")
try:
    x = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error")
# Out:
# ERROR:root:Division by zero error

# %%
#Write a Python program that prints the content of a file and handles the case when the file is empty
with open("data.txt", "r") as f:
    content = f.read()
    if content:
        print(content)
    else:
        print("File is empty.")
# Out:
# New line
# Appended line.
# New line added.

# %%
# Demonstrate how to use memory profiling to check the memory usage of a small program
# !pip install memory-profiler

# %%
# Now, run the script using memory_profiler
# !python -m memory_profiler mem_profile_script.py
# Out:
# Filename: mem_profile_script.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# ...
#      3     41.5 MiB     41.5 MiB           1   @profile
#      4                                         def create_large_list():
#      5                                             # Create a list of 1 million integers to demonstrate memory usage
#      6     80.2 MiB     38.7 MiB     1000001       a = [i for i in range(1000000)]
#      7     80.2 MiB      0.0 MiB           1       return a

# %%
# %%writefile mem_profile_script.py
from memory_profiler import profile

@profile
def create_large_list():
    # Create a list of 1 million integers to demonstrate memory usage
    a = [i for i in range(1000000)]
    return a

if __name__ == '__main__':
    # Call the function to profile its memory usage
    _ = create_large_list()
# Out:
# Writing mem_profile_script.py

# %%
#Write a Python program to create and write a list of numbers to a file, one number per line

nums = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    for n in nums:
        f.write(str(n) + "\n")

# %%
#How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
logging.basicConfig(handlers=[handler], level=logging.INFO)

logging.info("Logging with rotation")

# %%
#Write a program that handles both IndexError and KeyError using a try-except block
lst = [1, 2]
d = {"a": 10}

try:
    print(lst[5])
    print(d["b"])
except IndexError:
    print("Index error occurred")
except KeyError:
    print("Key error occurred")
# Out:
# Index error occurred

# %%
#How would you open a file and read its contents using a context manager in Python
with open("data.txt", "r") as f:
    print(f.read())
# Out:
# New line
# Appended line.
# New line added.

# %%
#Write a Python program that reads a file and prints the number of occurrences of a specific word
word = "python"
count = 0

with open("data.txt", "r") as f:
    for line in f:
        count += line.lower().split().count(word)

print("Occurrences:", count)
# Out:
# Occurrences: 0

# %%
#How can you check if a file is empty before attempting to read its contents
import os

if os.path.getsize("data.txt") == 0:
    print("File is empty")
else:
    print("File has content")
# Out:
# File has content

# %%
#Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

try:
    with open("missing.txt", "r") as f:
        print(f.read())
except Exception as e:
    logging.error("File handling error: %s", e)
# Out:
# ERROR:root:File handling error: [Errno 2] No such file or directory: 'missing.txt'
